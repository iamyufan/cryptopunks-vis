# %%
import time
import json
import pandas as pd
import numpy as np

# %%
# PATHs

## The directory where the dune data is stored
DUNE_DATA_PATH = '../dune_data'

## The directory where the cryptopunk data with attributes info is stored
CSV_PATH = '../cp'

## The directory where the three databases are stored
DATABASE_PATH = '../database'

## The directory where the cryptopunk images is stored
PUNK_IMG_PATH='../punk_imgs'

## The directory where the visualization data for each visualization is stored
VIS_DATA_PATH = '../vis_data'

## The directory where the scraped tweets data is stored
TWEET_PATH = '../tweets'

# %%
# read transaction database
tx_db = pd.read_csv('{}/tx_db.csv'.format(DATABASE_PATH), index_col=0)

# read cryptopunk database
punk_db = pd.read_csv('{}/punk_db.csv'.format(DATABASE_PATH), index_col=0)
punk_db['attributes'] = punk_db['attributes'].apply(eval)

# read trader database
trader_db = pd.read_csv('{}/trader_db.csv'.format(DATABASE_PATH), index_col=0)

# %% [markdown]
# ### 1. Sankey Diagram
#
# <img src="../imgs/vis1_example.png" alt="drawing" width="500">
#
# Data format
#
# ```
# {
#     "nodes":[
#         {"node":0,"name":"Human"},
#         {"node":1,"name":"Zombie"},
#         {"node":2,"name":"Ape"},
#         {"node":3,"name":"Alien"},
#
#         {"node":4,"name":"Female"},
#         {"node":5,"name":"Male"},
#
#         {"node":6,"name":"Medium"},
#         {"node":7,"name":"Dark"},
#         {"node":8,"name":"Light"},
#         {"node":9,"name":"Albino"},
#         {"node":10,"name":"non-human"},
#
#         {"node":11,"name":"Beanie"},
#         ...
#         {"node":97,"name":"Stringy Hair"}
#     ],
#
#     "links":[
#         {"source":<node_id>, "target":<node_id>, "value":<count>},
#         ...
#     ]
# }
# ```

# %%
def between_skin_tone_and_attributes(item, source_skin_tone, target_attribute):
    return (item['skin_tone'] == source_skin_tone) and (target_attribute in item['attributes'])


def get_dataset_vis1(tx_db, punk_db, trader_db):
    dataset_vis1 = dict()

    # nodes
    node_names_nested_list = list()
    # get the list of all types
    # ['Human', 'Zombie', 'Ape', 'Alien']
    type_list = list(punk_db['type'].unique())
    node_names_nested_list.append(type_list)

    # get the list of all genders
    gender_list = list(punk_db['gender'].unique()
                       )          # ['Female', 'Male']
    node_names_nested_list.append(gender_list)

    # get the list of all skin_stones
    # ['Medium', 'Dark', 'Light', 'Albino', '']
    skin_tone_list = list(punk_db['skin_tone'].unique())
    skin_tone_list = [st for st in skin_tone_list if not pd.isna(st)]
    print(skin_tone_list)
    # skin_tone_list.remove('')
    # skin_tone_list = [
    #     x if x != '' else 'Unknown_skin_tone' for x in skin_tone_list]
    node_names_nested_list.append(skin_tone_list)

    # get the list of all attributes
    attribute_list = list(punk_db.attributes)
    attribute_list = list(
        set([item for elem in attribute_list for item in elem]))
    attribute_list = sorted(attribute_list)
    attribute_list.remove('')
    # attribute_list = [
    #     x if x != '' else 'No attributes' for x in attribute_list]
    node_names_nested_list.append(attribute_list)

    # set node_id and node_name
    node_list = list()

    node_names = type_list + gender_list + skin_tone_list + attribute_list
    for name in node_names:
        node_list.append({'node': len(node_list), 'name': name})

    dataset_vis1['nodes'] = node_list
    print('> Saved: nodes')

    # links
    link_list = list()
    levels_list = ['type', 'gender', 'skin_tone']
    # links between each pair of neighbor levels
    for i in range(len(levels_list)-1):
        source_level = levels_list[i]
        source_name_list = node_names_nested_list[i]

        target_level = levels_list[i+1]
        target_name_list = node_names_nested_list[i+1]

        for source in source_name_list:
            for target in target_name_list:
                value = punk_db[(punk_db[source_level] == source) & (
                    punk_db[target_level] == target)].shape[0]
                link_list.append(
                    {'source': source, 'target': target, 'value': value})
    print('>> Saved: links between type, gender, and skin_tone')

    # links between skin_tone and attributes
    for source in skin_tone_list:
        for target in attribute_list:
            value = punk_db[punk_db.apply(lambda x: between_skin_tone_and_attributes(
                x, source, target), axis=1)].shape[0]
            link_list.append(
                {'source': source, 'target': target, 'value': value})
    print('>> Saved: links between skin_tone and attributes')

    dataset_vis1['links'] = link_list
    print('> Saved: links')

    return dataset_vis1


vis1_data = get_dataset_vis1(tx_db, punk_db, trader_db)
with open('{}/vis1_data.json'.format(VIS_DATA_PATH), 'w') as f:
    json.dump(vis1_data, f)
vis1_data
# Out:
# ['Medium', 'Dark', 'Light', 'Albino']
# > Saved: nodes
# >> Saved: links between type, gender, and skin_tone
# >> Saved: links between skin_tone and attributes
# > Saved: links
# {'nodes': [{'node': 0, 'name': 'Human'},
#   {'node': 1, 'name': 'Zombie'},
#   {'node': 2, 'name': 'Ape'},
#   {'node': 3, 'name': 'Alien'},
#   {'node': 4, 'name': 'Female'},
#   {'node': 5, 'name': 'Male'},
#   {'node': 6, 'name': 'Medium'},
#   {'node': 7, 'name': 'Dark'},
#   {'node': 8, 'name': 'Light'},
#   {'node': 9, 'name': 'Albino'},
#   {'node': 10, 'name': '3D Glasses'},
#   {'node': 11, 'name': 'Bandana'},
#   {'node': 12, 'name': 'Beanie'},
#   {'node': 13, 'name': 'Big Beard'},
#   {'node': 14, 'name': 'Big Shades'},
#   {'node': 15, 'name': 'Black Lipstick'},
#   {'node': 16, 'name': 'Blonde Bob'},
#   {'node': 17, 'name': 'Blonde Short'},
#   {'node': 18, 'name': 'Blue Eye Shadow'},
#   {'node': 19, 'name': 'Buck Teeth'},
#   {'node': 20, 'name': 'Cap'},
#   {'node': 21, 'name': 'Cap Forward'},
#   {'node': 22, 'name': 'Chinstrap'},
#   {'node': 23, 'name': 'Choker'},
#   {'node': 24, 'name': 'Cigarette'},
#   {'node': 25, 'name': 'Classic Shades'},
#   {'node': 26, 'name': 'Clown Eyes Blue'},
#   {'node': 27, 'name': 'Clown Eyes Green'},
#   {'node': 28, 'name': 'Clown Hair Green'},
#   {'node': 29, 'name': 'Clown Nose'},
#   {'node': 30, 'name': 'Cowboy Hat'},
#   {'node': 31, 'name': 'Crazy Hair'},
#   {'node': 32, 'name': 'Dark Hair'},
#   {'node': 33, 'name': 'Do-rag'},
#   {'node': 34, 'name': 'Earring'},
#   {'node': 35, 'name': 'Eye Mask'},
#   {'node': 36, 'name': 'Eye Patch'},
#   {'node': 37, 'name': 'Fedora'},
#   {'node': 38, 'name': 'Front Beard'},
#   {'node': 39, 'name': 'Front Beard Dark'},
#   {'node': 40, 'name': 'Frown'},
#   {'node': 41, 'name': 'Frumpy Hair'},
#   {'node': 42, 'name': 'Goat'},
#   {'node': 43, 'name': 'Gold Chain'},
#   {'node': 44, 'name': 'Green Eye Shadow'},
#   {'node': 45, 'name': 'Half Shaved'},
#   {'node': 46, 'name': 'Handlebars'},
#   {'node': 47, 'name': 'Headband'},
#   {'node': 48, 'name': 'Hoodie'},
#   {'node': 49, 'name': 'Horned Rim Glasses'},
#   {'node': 50, 'name': 'Hot Lipstick'},
#   {'node': 51, 'name': 'Knitted Cap'},
#   {'node': 52, 'name': 'Luxurious Beard'},
#   {'node': 53, 'name': 'Medical Mask'},
#   {'node': 54, 'name': 'Messy Hair'},
#   {'node': 55, 'name': 'Mohawk'},
#   {'node': 56, 'name': 'Mohawk Dark'},
#   {'node': 57, 'name': 'Mohawk Thin'},
#   {'node': 58, 'name': 'Mole'},
#   {'node': 59, 'name': 'Mustache'},
#   {'node': 60, 'name': 'Muttonchops'},
#   {'node': 61, 'name': 'Nerd Glasses'},
#   {'node': 62, 'name': 'Normal Beard'},
#   {'node': 63, 'name': 'Normal Beard Black'},
#   {'node': 64, 'name': 'Orange Side'},
#   {'node': 65, 'name': 'Peak Spike'},
#   {'node': 66, 'name': 'Pigtails'},
#   {'node': 67, 'name': 'Pilot Helmet'},
#   {'node': 68, 'name': 'Pink With Hat'},
#   {'node': 69, 'name': 'Pipe'},
#   {'node': 70, 'name': 'Police Cap'},
#   {'node': 71, 'name': 'Purple Eye Shadow'},
#   {'node': 72, 'name': 'Purple Hair'},
#   {'node': 73, 'name': 'Purple Lipstick'},
#   {'node': 74, 'name': 'Red Mohawk'},
#   {'node': 75, 'name': 'Regular Shades'},
#   {'node': 76, 'name': 'Rosy Cheeks'},
#   {'node': 77, 'name': 'Shadow Beard'},
#   {'node': 78, 'name': 'Shaved Head'},
#   {'node': 79, 'name': 'Silver Chain'},
#   {'node': 80, 'name': 'Small Shades'},
#   {'node': 81, 'name': 'Smile'},
#   {'node': 82, 'name': 'Spots'},
#   {'node': 83, 'name': 'Straight Hair'},
#   {'node': 84, 'name': 'Straight Hair Blonde'},
#   {'node': 85, 'name': 'Straight Hair Dark'},
#   {'node': 86, 'name': 'Stringy Hair'},
#   {'node': 87, 'name': 'Tassle Hat'},
#   {'node': 88, 'name': 'Tiara'},
#   {'node': 89, 'name': 'Top Hat'},
#   {'node': 90, 'name': 'VR'},
#   {'node': 91, 'name': 'Vampire Hair'},
#   {'node': 92, 'name': 'Vape'},
#   {'node': 93, 'name': 'Welding Goggles'},
#   {'node': 94, 'name': 'Wild Blonde'},
#   {'node': 95, 'name': 'Wild Hair'},
#   {'node': 96, 'name': 'Wild White Hair'}],
#  'links': [{'source': 'Human', 'target': 'Female', 'value': 3840},
#   {'source': 'Human', 'target': 'Male', 'value': 6039},
#   {'source': 'Zombie', 'target': 'Female', 'value': 0},
#   {'source': 'Zombie', 'target': 'Male', 'value': 88},
#   {'source': 'Ape', 'target': 'Female', 'value': 0},
#   {'source': 'Ape', 'target': 'Male', 'value': 24},
#   {'source': 'Alien', 'target': 'Female', 'value': 0},
#   {'source': 'Alien', 'target': 'Male', 'value': 9},
#   {'source': 'Female', 'target': 'Medium', 'value': 1174},
#   {'source': 'Female', 'target': 'Dark', 'value': 1101},
#   {'source': 'Female', 'target': 'Light', 'value': 1145},
#   {'source': 'Female', 'target': 'Albino', 'value': 420},
#   {'source': 'Male', 'target': 'Medium', 'value': 1857},
#   {'source': 'Male', 'target': 'Dark', 'value': 1723},
#   {'source': 'Male', 'target': 'Light', 'value': 1861},
#   {'source': 'Male', 'target': 'Albino', 'value': 598},
#   {'source': 'Medium', 'target': '3D Glasses', 'value': 99},
#   {'source': 'Medium', 'target': 'Bandana', 'value': 161},
#   {'source': 'Medium', 'target': 'Beanie', 'value': 10},
#   {'source': 'Medium', 'target': 'Big Beard', 'value': 50},
#   {'source': 'Medium', 'target': 'Big Shades', 'value': 164},
#   {'source': 'Medium', 'target': 'Black Lipstick', 'value': 189},
#   {'source': 'Medium', 'target': 'Blonde Bob', 'value': 39},
#   {'source': 'Medium', 'target': 'Blonde Short', 'value': 40},
#   {'source': 'Medium', 'target': 'Blue Eye Shadow', 'value': 101},
#   {'source': 'Medium', 'target': 'Buck Teeth', 'value': 30},
#   {'source': 'Medium', 'target': 'Cap', 'value': 102},
#   {'source': 'Medium', 'target': 'Cap Forward', 'value': 80},
#   {'source': 'Medium', 'target': 'Chinstrap', 'value': 87},
#   {'source': 'Medium', 'target': 'Choker', 'value': 16},
#   {'source': 'Medium', 'target': 'Cigarette', 'value': 311},
#   {'source': 'Medium', 'target': 'Classic Shades', 'value': 150},
#   {'source': 'Medium', 'target': 'Clown Eyes Blue', 'value': 119},
#   {'source': 'Medium', 'target': 'Clown Eyes Green', 'value': 116},
#   {'source': 'Medium', 'target': 'Clown Hair Green', 'value': 40},
#   {'source': 'Medium', 'target': 'Clown Nose', 'value': 60},
#   {'source': 'Medium', 'target': 'Cowboy Hat', 'value': 48},
#   {'source': 'Medium', 'target': 'Crazy Hair', 'value': 124},
#   {'source': 'Medium', 'target': 'Dark Hair', 'value': 53},
#   {'source': 'Medium', 'target': 'Do-rag', 'value': 89},
#   {'source': 'Medium', 'target': 'Earring', 'value': 790},
#   {'source': 'Medium', 'target': 'Eye Mask', 'value': 89},
#   {'source': 'Medium', 'target': 'Eye Patch', 'value': 127},
#   {'source': 'Medium', 'target': 'Fedora', 'value': 47},
#   {'source': 'Medium', 'target': 'Front Beard', 'value': 85},
#   {'source': 'Medium', 'target': 'Front Beard Dark', 'value': 84},
#   {'source': 'Medium', 'target': 'Frown', 'value': 67},
#   {'source': 'Medium', 'target': 'Frumpy Hair', 'value': 142},
#   {'source': 'Medium', 'target': 'Goat', 'value': 95},
#   {'source': 'Medium', 'target': 'Gold Chain', 'value': 52},
#   {'source': 'Medium', 'target': 'Green Eye Shadow', 'value': 83},
#   {'source': 'Medium', 'target': 'Half Shaved', 'value': 42},
#   {'source': 'Medium', 'target': 'Handlebars', 'value': 90},
#   {'source': 'Medium', 'target': 'Headband', 'value': 142},
#   {'source': 'Medium', 'target': 'Hoodie', 'value': 83},
#   {'source': 'Medium', 'target': 'Horned Rim Glasses', 'value': 154},
#   {'source': 'Medium', 'target': 'Hot Lipstick', 'value': 219},
#   {'source': 'Medium', 'target': 'Knitted Cap', 'value': 119},
#   {'source': 'Medium', 'target': 'Luxurious Beard', 'value': 81},
#   {'source': 'Medium', 'target': 'Medical Mask', 'value': 55},
#   {'source': 'Medium', 'target': 'Messy Hair', 'value': 144},
#   {'source': 'Medium', 'target': 'Mohawk', 'value': 135},
#   {'source': 'Medium', 'target': 'Mohawk Dark', 'value': 134},
#   {'source': 'Medium', 'target': 'Mohawk Thin', 'value': 121},
#   {'source': 'Medium', 'target': 'Mole', 'value': 190},
#   {'source': 'Medium', 'target': 'Mustache', 'value': 90},
#   {'source': 'Medium', 'target': 'Muttonchops', 'value': 83},
#   {'source': 'Medium', 'target': 'Nerd Glasses', 'value': 179},
#   {'source': 'Medium', 'target': 'Normal Beard', 'value': 106},
#   {'source': 'Medium', 'target': 'Normal Beard Black', 'value': 91},
#   {'source': 'Medium', 'target': 'Orange Side', 'value': 18},
#   {'source': 'Medium', 'target': 'Peak Spike', 'value': 92},
#   {'source': 'Medium', 'target': 'Pigtails', 'value': 31},
#   {'source': 'Medium', 'target': 'Pilot Helmet', 'value': 18},
#   {'source': 'Medium', 'target': 'Pink With Hat', 'value': 26},
#   {'source': 'Medium', 'target': 'Pipe', 'value': 98},
#   {'source': 'Medium', 'target': 'Police Cap', 'value': 47},
#   {'source': 'Medium', 'target': 'Purple Eye Shadow', 'value': 88},
#   {'source': 'Medium', 'target': 'Purple Hair', 'value': 48},
#   {'source': 'Medium', 'target': 'Purple Lipstick', 'value': 198},
#   {'source': 'Medium', 'target': 'Red Mohawk', 'value': 42},
#   {'source': 'Medium', 'target': 'Regular Shades', 'value': 165},
#   {'source': 'Medium', 'target': 'Rosy Cheeks', 'value': 41},
#   {'source': 'Medium', 'target': 'Shadow Beard', 'value': 146},
#   {'source': 'Medium', 'target': 'Shaved Head', 'value': 86},
#   {'source': 'Medium', 'target': 'Silver Chain', 'value': 52},
#   {'source': 'Medium', 'target': 'Small Shades', 'value': 129},
#   {'source': 'Medium', 'target': 'Smile', 'value': 78},
#   {'source': 'Medium', 'target': 'Spots', 'value': 40},
#   {'source': 'Medium', 'target': 'Straight Hair', 'value': 44},
#   {'source': 'Medium', 'target': 'Straight Hair Blonde', 'value': 46},
#   {'source': 'Medium', 'target': 'Straight Hair Dark', 'value': 44},
#   {'source': 'Medium', 'target': 'Stringy Hair', 'value': 138},
#   {'source': 'Medium', 'target': 'Tassle Hat', 'value': 51},
#   {'source': 'Medium', 'target': 'Tiara', 'value': 17},
#   {'source': 'Medium', 'target': 'Top Hat', 'value': 43},
#   {'source': 'Medium', 'target': 'VR', 'value': 109},
#   {'source': 'Medium', 'target': 'Vampire Hair', 'value': 39},
#   {'source': 'Medium', 'target': 'Vape', 'value': 83},
#   {'source': 'Medium', 'target': 'Welding Goggles', 'value': 27},
#   {'source': 'Medium', 'target': 'Wild Blonde', 'value': 47},
#   {'source': 'Medium', 'target': 'Wild Hair', 'value': 138},
#   {'source': 'Medium', 'target': 'Wild White Hair', 'value': 40},
#   {'source': 'Dark', 'target': '3D Glasses', 'value': 74},
#   {'source': 'Dark', 'target': 'Bandana', 'value': 119},
#   {'source': 'Dark', 'target': 'Beanie', 'value': 15},
#   {'source': 'Dark', 'target': 'Big Beard', 'value': 49},
#   {'source': 'Dark', 'target': 'Big Shades', 'value': 158},
#   {'source': 'Dark', 'target': 'Black Lipstick', 'value': 171},
#   {'source': 'Dark', 'target': 'Blonde Bob', 'value': 44},
#   {'source': 'Dark', 'target': 'Blonde Short', 'value': 35},
#   {'source': 'Dark', 'target': 'Blue Eye Shadow', 'value': 67},
#   {'source': 'Dark', 'target': 'Buck Teeth', 'value': 25},
#   {'source': 'Dark', 'target': 'Cap', 'value': 90},
#   {'source': 'Dark', 'target': 'Cap Forward', 'value': 72},
#   {'source': 'Dark', 'target': 'Chinstrap', 'value': 74},
#   {'source': 'Dark', 'target': 'Choker', 'value': 17},
#   {'source': 'Dark', 'target': 'Cigarette', 'value': 264},
#   {'source': 'Dark', 'target': 'Classic Shades', 'value': 142},
#   {'source': 'Dark', 'target': 'Clown Eyes Blue', 'value': 121},
#   {'source': 'Dark', 'target': 'Clown Eyes Green', 'value': 104},
#   {'source': 'Dark', 'target': 'Clown Hair Green', 'value': 41},
#   {'source': 'Dark', 'target': 'Clown Nose', 'value': 65},
#   {'source': 'Dark', 'target': 'Cowboy Hat', 'value': 31},
#   {'source': 'Dark', 'target': 'Crazy Hair', 'value': 109},
#   {'source': 'Dark', 'target': 'Dark Hair', 'value': 52},
#   {'source': 'Dark', 'target': 'Do-rag', 'value': 88},
#   {'source': 'Dark', 'target': 'Earring', 'value': 682},
#   {'source': 'Dark', 'target': 'Eye Mask', 'value': 82},
#   {'source': 'Dark', 'target': 'Eye Patch', 'value': 137},
#   {'source': 'Dark', 'target': 'Fedora', 'value': 64},
#   {'source': 'Dark', 'target': 'Front Beard', 'value': 85},
#   {'source': 'Dark', 'target': 'Front Beard Dark', 'value': 60},
#   {'source': 'Dark', 'target': 'Frown', 'value': 84},
#   {'source': 'Dark', 'target': 'Frumpy Hair', 'value': 119},
#   {'source': 'Dark', 'target': 'Goat', 'value': 86},
#   {'source': 'Dark', 'target': 'Gold Chain', 'value': 48},
#   {'source': 'Dark', 'target': 'Green Eye Shadow', 'value': 79},
#   {'source': 'Dark', 'target': 'Half Shaved', 'value': 45},
#   {'source': 'Dark', 'target': 'Handlebars', 'value': 68},
#   {'source': 'Dark', 'target': 'Headband', 'value': 105},
#   {'source': 'Dark', 'target': 'Hoodie', 'value': 74},
#   {'source': 'Dark', 'target': 'Horned Rim Glasses', 'value': 161},
#   {'source': 'Dark', 'target': 'Hot Lipstick', 'value': 201},
#   {'source': 'Dark', 'target': 'Knitted Cap', 'value': 123},
#   {'source': 'Dark', 'target': 'Luxurious Beard', 'value': 102},
#   {'source': 'Dark', 'target': 'Medical Mask', 'value': 49},
#   {'source': 'Dark', 'target': 'Messy Hair', 'value': 134},
#   {'source': 'Dark', 'target': 'Mohawk', 'value': 133},
#   {'source': 'Dark', 'target': 'Mohawk Dark', 'value': 119},
#   {'source': 'Dark', 'target': 'Mohawk Thin', 'value': 131},
#   {'source': 'Dark', 'target': 'Mole', 'value': 195},
#   {'source': 'Dark', 'target': 'Mustache', 'value': 72},
#   {'source': 'Dark', 'target': 'Muttonchops', 'value': 100},
#   {'source': 'Dark', 'target': 'Nerd Glasses', 'value': 155},
#   {'source': 'Dark', 'target': 'Normal Beard', 'value': 66},
#   {'source': 'Dark', 'target': 'Normal Beard Black', 'value': 85},
#   {'source': 'Dark', 'target': 'Orange Side', 'value': 21},
#   {'source': 'Dark', 'target': 'Peak Spike', 'value': 83},
#   {'source': 'Dark', 'target': 'Pigtails', 'value': 22},
#   {'source': 'Dark', 'target': 'Pilot Helmet', 'value': 14},
#   {'source': 'Dark', 'target': 'Pink With Hat', 'value': 35},
#   {'source': 'Dark', 'target': 'Pipe', 'value': 83},
#   {'source': 'Dark', 'target': 'Police Cap', 'value': 67},
#   {'source': 'Dark', 'target': 'Purple Eye Shadow', 'value': 72},
#   {'source': 'Dark', 'target': 'Purple Hair', 'value': 46},
#   {'source': 'Dark', 'target': 'Purple Lipstick', 'value': 189},
#   {'source': 'Dark', 'target': 'Red Mohawk', 'value': 43},
#   {'source': 'Dark', 'target': 'Regular Shades', 'value': 145},
#   {'source': 'Dark', 'target': 'Rosy Cheeks', 'value': 40},
#   {'source': 'Dark', 'target': 'Shadow Beard', 'value': 166},
#   {'source': 'Dark', 'target': 'Shaved Head', 'value': 95},
#   {'source': 'Dark', 'target': 'Silver Chain', 'value': 39},
#   {'source': 'Dark', 'target': 'Small Shades', 'value': 96},
#   {'source': 'Dark', 'target': 'Smile', 'value': 72},
#   {'source': 'Dark', 'target': 'Spots', 'value': 33},
#   {'source': 'Dark', 'target': 'Straight Hair', 'value': 42},
#   {'source': 'Dark', 'target': 'Straight Hair Blonde', 'value': 41},
#   {'source': 'Dark', 'target': 'Straight Hair Dark', 'value': 42},
#   {'source': 'Dark', 'target': 'Stringy Hair', 'value': 131},
#   {'source': 'Dark', 'target': 'Tassle Hat', 'value': 53},
#   {'source': 'Dark', 'target': 'Tiara', 'value': 14},
#   {'source': 'Dark', 'target': 'Top Hat', 'value': 33},
#   {'source': 'Dark', 'target': 'VR', 'value': 82},
#   {'source': 'Dark', 'target': 'Vampire Hair', 'value': 45},
#   {'source': 'Dark', 'target': 'Vape', 'value': 75},
#   {'source': 'Dark', 'target': 'Welding Goggles', 'value': 30},
#   {'source': 'Dark', 'target': 'Wild Blonde', 'value': 33},
#   {'source': 'Dark', 'target': 'Wild Hair', 'value': 118},
#   {'source': 'Dark', 'target': 'Wild White Hair', 'value': 40},
#   {'source': 'Light', 'target': '3D Glasses', 'value': 91},
#   {'source': 'Light', 'target': 'Bandana', 'value': 140},
#   {'source': 'Light', 'target': 'Beanie', 'value': 15},
#   {'source': 'Light', 'target': 'Big Beard', 'value': 38},
#   {'source': 'Light', 'target': 'Big Shades', 'value': 155},
#   {'source': 'Light', 'target': 'Black Lipstick', 'value': 195},
#   {'source': 'Light', 'target': 'Blonde Bob', 'value': 46},
#   {'source': 'Light', 'target': 'Blonde Short', 'value': 41},
#   {'source': 'Light', 'target': 'Blue Eye Shadow', 'value': 75},
#   {'source': 'Light', 'target': 'Buck Teeth', 'value': 19},
#   {'source': 'Light', 'target': 'Cap', 'value': 106},
#   {'source': 'Light', 'target': 'Cap Forward', 'value': 71},
#   {'source': 'Light', 'target': 'Chinstrap', 'value': 89},
#   {'source': 'Light', 'target': 'Choker', 'value': 13},
#   {'source': 'Light', 'target': 'Cigarette', 'value': 277},
#   {'source': 'Light', 'target': 'Classic Shades', 'value': 165},
#   {'source': 'Light', 'target': 'Clown Eyes Blue', 'value': 113},
#   {'source': 'Light', 'target': 'Clown Eyes Green', 'value': 119},
#   {'source': 'Light', 'target': 'Clown Hair Green', 'value': 49},
#   {'source': 'Light', 'target': 'Clown Nose', 'value': 74},
#   {'source': 'Light', 'target': 'Cowboy Hat', 'value': 48},
#   {'source': 'Light', 'target': 'Crazy Hair', 'value': 141},
#   {'source': 'Light', 'target': 'Dark Hair', 'value': 39},
#   {'source': 'Light', 'target': 'Do-rag', 'value': 88},
#   {'source': 'Light', 'target': 'Earring', 'value': 732},
#   {'source': 'Light', 'target': 'Eye Mask', 'value': 96},
#   {'source': 'Light', 'target': 'Eye Patch', 'value': 142},
#   {'source': 'Light', 'target': 'Fedora', 'value': 58},
#   {'source': 'Light', 'target': 'Front Beard', 'value': 81},
#   {'source': 'Light', 'target': 'Front Beard Dark', 'value': 88},
#   {'source': 'Light', 'target': 'Frown', 'value': 87},
#   {'source': 'Light', 'target': 'Frumpy Hair', 'value': 128},
#   {'source': 'Light', 'target': 'Goat', 'value': 85},
#   {'source': 'Light', 'target': 'Gold Chain', 'value': 52},
#   {'source': 'Light', 'target': 'Green Eye Shadow', 'value': 82},
#   {'source': 'Light', 'target': 'Half Shaved', 'value': 42},
#   {'source': 'Light', 'target': 'Handlebars', 'value': 84},
#   {'source': 'Light', 'target': 'Headband', 'value': 116},
#   {'source': 'Light', 'target': 'Hoodie', 'value': 72},
#   {'source': 'Light', 'target': 'Horned Rim Glasses', 'value': 174},
#   {'source': 'Light', 'target': 'Hot Lipstick', 'value': 200},
#   {'source': 'Light', 'target': 'Knitted Cap', 'value': 124},
#   {'source': 'Light', 'target': 'Luxurious Beard', 'value': 72},
#   {'source': 'Light', 'target': 'Medical Mask', 'value': 55},
#   {'source': 'Light', 'target': 'Messy Hair', 'value': 128},
#   {'source': 'Light', 'target': 'Mohawk', 'value': 122},
#   {'source': 'Light', 'target': 'Mohawk Dark', 'value': 132},
#   {'source': 'Light', 'target': 'Mohawk Thin', 'value': 149},
#   {'source': 'Light', 'target': 'Mole', 'value': 192},
#   {'source': 'Light', 'target': 'Mustache', 'value': 96},
#   {'source': 'Light', 'target': 'Muttonchops', 'value': 97},
#   {'source': 'Light', 'target': 'Nerd Glasses', 'value': 187},
#   {'source': 'Light', 'target': 'Normal Beard', 'value': 91},
#   {'source': 'Light', 'target': 'Normal Beard Black', 'value': 85},
#   {'source': 'Light', 'target': 'Orange Side', 'value': 22},
#   {'source': 'Light', 'target': 'Peak Spike', 'value': 94},
#   {'source': 'Light', 'target': 'Pigtails', 'value': 33},
#   {'source': 'Light', 'target': 'Pilot Helmet', 'value': 17},
#   {'source': 'Light', 'target': 'Pink With Hat', 'value': 28},
#   {'source': 'Light', 'target': 'Pipe', 'value': 108},
#   {'source': 'Light', 'target': 'Police Cap', 'value': 61},
#   {'source': 'Light', 'target': 'Purple Eye Shadow', 'value': 76},
#   {'source': 'Light', 'target': 'Purple Hair', 'value': 47},
#   {'source': 'Light', 'target': 'Purple Lipstick', 'value': 195},
#   {'source': 'Light', 'target': 'Red Mohawk', 'value': 45},
#   {'source': 'Light', 'target': 'Regular Shades', 'value': 157},
#   {'source': 'Light', 'target': 'Rosy Cheeks', 'value': 41},
#   {'source': 'Light', 'target': 'Shadow Beard', 'value': 164},
#   {'source': 'Light', 'target': 'Shaved Head', 'value': 88},
#   {'source': 'Light', 'target': 'Silver Chain', 'value': 49},
#   {'source': 'Light', 'target': 'Small Shades', 'value': 112},
#   {'source': 'Light', 'target': 'Smile', 'value': 62},
#   {'source': 'Light', 'target': 'Spots', 'value': 38},
#   {'source': 'Light', 'target': 'Straight Hair', 'value': 45},
#   {'source': 'Light', 'target': 'Straight Hair Blonde', 'value': 43},
#   {'source': 'Light', 'target': 'Straight Hair Dark', 'value': 46},
#   {'source': 'Light', 'target': 'Stringy Hair', 'value': 140},
#   {'source': 'Light', 'target': 'Tassle Hat', 'value': 52},
#   {'source': 'Light', 'target': 'Tiara', 'value': 16},
#   {'source': 'Light', 'target': 'Top Hat', 'value': 30},
#   {'source': 'Light', 'target': 'VR', 'value': 100},
#   {'source': 'Light', 'target': 'Vampire Hair', 'value': 54},
#   {'source': 'Light', 'target': 'Vape', 'value': 92},
#   {'source': 'Light', 'target': 'Welding Goggles', 'value': 23},
#   {'source': 'Light', 'target': 'Wild Blonde', 'value': 48},
#   {'source': 'Light', 'target': 'Wild Hair', 'value': 126},
#   {'source': 'Light', 'target': 'Wild White Hair', 'value': 40},
#   {'source': 'Albino', 'target': '3D Glasses', 'value': 19},
#   {'source': 'Albino', 'target': 'Bandana', 'value': 48},
#   {'source': 'Albino', 'target': 'Beanie', 'value': 3},
#   {'source': 'Albino', 'target': 'Big Beard', 'value': 9},
#   {'source': 'Albino', 'target': 'Big Shades', 'value': 54},
#   {'source': 'Albino', 'target': 'Black Lipstick', 'value': 62},
#   {'source': 'Albino', 'target': 'Blonde Bob', 'value': 18},
#   {'source': 'Albino', 'target': 'Blonde Short', 'value': 13},
#   {'source': 'Albino', 'target': 'Blue Eye Shadow', 'value': 23},
#   {'source': 'Albino', 'target': 'Buck Teeth', 'value': 4},
#   {'source': 'Albino', 'target': 'Cap', 'value': 45},
#   {'source': 'Albino', 'target': 'Cap Forward', 'value': 25},
#   {'source': 'Albino', 'target': 'Chinstrap', 'value': 30},
#   {'source': 'Albino', 'target': 'Choker', 'value': 2},
#   {'source': 'Albino', 'target': 'Cigarette', 'value': 97},
#   {'source': 'Albino', 'target': 'Classic Shades', 'value': 42},
#   {'source': 'Albino', 'target': 'Clown Eyes Blue', 'value': 29},
#   {'source': 'Albino', 'target': 'Clown Eyes Green', 'value': 43},
#   {'source': 'Albino', 'target': 'Clown Hair Green', 'value': 18},
#   {'source': 'Albino', 'target': 'Clown Nose', 'value': 11},
#   {'source': 'Albino', 'target': 'Cowboy Hat', 'value': 12},
#   {'source': 'Albino', 'target': 'Crazy Hair', 'value': 33},
#   {'source': 'Albino', 'target': 'Dark Hair', 'value': 13},
#   {'source': 'Albino', 'target': 'Do-rag', 'value': 27},
#   {'source': 'Albino', 'target': 'Earring', 'value': 227},
#   {'source': 'Albino', 'target': 'Eye Mask', 'value': 24},
#   {'source': 'Albino', 'target': 'Eye Patch', 'value': 49},
#   {'source': 'Albino', 'target': 'Fedora', 'value': 15},
#   {'source': 'Albino', 'target': 'Front Beard', 'value': 19},
#   {'source': 'Albino', 'target': 'Front Beard Dark', 'value': 23},
#   {'source': 'Albino', 'target': 'Frown', 'value': 19},
#   {'source': 'Albino', 'target': 'Frumpy Hair', 'value': 49},
#   {'source': 'Albino', 'target': 'Goat', 'value': 26},
#   {'source': 'Albino', 'target': 'Gold Chain', 'value': 15},
#   {'source': 'Albino', 'target': 'Green Eye Shadow', 'value': 27},
#   {'source': 'Albino', 'target': 'Half Shaved', 'value': 18},
#   {'source': 'Albino', 'target': 'Handlebars', 'value': 19},
#   {'source': 'Albino', 'target': 'Headband', 'value': 37},
#   {'source': 'Albino', 'target': 'Hoodie', 'value': 27},
#   {'source': 'Albino', 'target': 'Horned Rim Glasses', 'value': 41},
#   {'source': 'Albino', 'target': 'Hot Lipstick', 'value': 76},
#   {'source': 'Albino', 'target': 'Knitted Cap', 'value': 40},
#   {'source': 'Albino', 'target': 'Luxurious Beard', 'value': 26},
#   {'source': 'Albino', 'target': 'Medical Mask', 'value': 13},
#   {'source': 'Albino', 'target': 'Messy Hair', 'value': 48},
#   {'source': 'Albino', 'target': 'Mohawk', 'value': 49},
#   {'source': 'Albino', 'target': 'Mohawk Dark', 'value': 40},
#   {'source': 'Albino', 'target': 'Mohawk Thin', 'value': 36},
#   {'source': 'Albino', 'target': 'Mole', 'value': 65},
#   {'source': 'Albino', 'target': 'Mustache', 'value': 28},
#   {'source': 'Albino', 'target': 'Muttonchops', 'value': 23},
#   {'source': 'Albino', 'target': 'Nerd Glasses', 'value': 46},
#   {'source': 'Albino', 'target': 'Normal Beard', 'value': 28},
#   {'source': 'Albino', 'target': 'Normal Beard Black', 'value': 25},
#   {'source': 'Albino', 'target': 'Orange Side', 'value': 7},
#   {'source': 'Albino', 'target': 'Peak Spike', 'value': 29},
#   {'source': 'Albino', 'target': 'Pigtails', 'value': 8},
#   {'source': 'Albino', 'target': 'Pilot Helmet', 'value': 5},
#   {'source': 'Albino', 'target': 'Pink With Hat', 'value': 6},
#   {'source': 'Albino', 'target': 'Pipe', 'value': 27},
#   {'source': 'Albino', 'target': 'Police Cap', 'value': 25},
#   {'source': 'Albino', 'target': 'Purple Eye Shadow', 'value': 26},
#   {'source': 'Albino', 'target': 'Purple Hair', 'value': 22},
#   {'source': 'Albino', 'target': 'Purple Lipstick', 'value': 73},
#   {'source': 'Albino', 'target': 'Red Mohawk', 'value': 17},
#   {'source': 'Albino', 'target': 'Regular Shades', 'value': 54},
#   {'source': 'Albino', 'target': 'Rosy Cheeks', 'value': 5},
#   {'source': 'Albino', 'target': 'Shadow Beard', 'value': 40},
#   {'source': 'Albino', 'target': 'Shaved Head', 'value': 29},
#   {'source': 'Albino', 'target': 'Silver Chain', 'value': 16},
#   {'source': 'Albino', 'target': 'Small Shades', 'value': 35},
#   {'source': 'Albino', 'target': 'Smile', 'value': 22},
#   {'source': 'Albino', 'target': 'Spots', 'value': 13},
#   {'source': 'Albino', 'target': 'Straight Hair', 'value': 20},
#   {'source': 'Albino', 'target': 'Straight Hair Blonde', 'value': 14},
#   {'source': 'Albino', 'target': 'Straight Hair Dark', 'value': 16},
#   {'source': 'Albino', 'target': 'Stringy Hair', 'value': 48},
#   {'source': 'Albino', 'target': 'Tassle Hat', 'value': 22},
#   {'source': 'Albino', 'target': 'Tiara', 'value': 8},
#   {'source': 'Albino', 'target': 'Top Hat', 'value': 6},
#   {'source': 'Albino', 'target': 'VR', 'value': 39},
#   {'source': 'Albino', 'target': 'Vampire Hair', 'value': 8},
#   {'source': 'Albino', 'target': 'Vape', 'value': 21},
#   {'source': 'Albino', 'target': 'Welding Goggles', 'value': 6},
#   {'source': 'Albino', 'target': 'Wild Blonde', 'value': 16},
#   {'source': 'Albino', 'target': 'Wild Hair', 'value': 58},
#   {'source': 'Albino', 'target': 'Wild White Hair', 'value': 16}]}
